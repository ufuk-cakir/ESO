# %%
import sys
import os

sys.path.append(
    os.path.abspath("/home/aaron-joel/Documents/PostDoc/Eso_Project_/ESO/src")
)

# %%
import numpy as np
import matplotlib.pyplot as plt
# import DataManager

from eso.utils.preprocessing import Preprocessing
# from Preprocessing import *
# from DataManager import *
# Out:
# 2023-11-22 10:57:45.335043: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from pathlib import Path

# %%
str(Path("test"))
# Out:
# 'test'

# %%
a = np.array([1, 2, 3, 4])

# %%
n = len(a)
import random

start_idx = random.randint(0, n - 1)
end_idx = n
print(start_idx, end_idx, n)
# Out:
# 2 4 4

# %%
list(range(start_idx, end_idx))
# Out:
# [2, 3]

# %%
list(range(3, end_idx))
# Out:
# [3]

# %%
# Let's ensure that the "whole" Chromosome is not changed.
# This situation occurs when start_idx = 0.
if start_idx == 0:
    end_idx = n - 1


parent2_genes = parent2.get_genes()

for k in range(start_idx, end_idx):
    offspring1.set_gene(
        k, parent2_genes[k].get_band_position(), parent2_genes[k].get_band_height()
    )
    offspring2.set_gene(
        k, parent1_genes[k].get_band_position(), parent1_genes[k].get_band_height()
    )

return (offspring1, offspring2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ufuk/1. Research/AIMS/Project Repo/ESO/src/eso/utils/Create_Dataset.ipynb Zelle 4 line 7
#       <a href='vscode-notebook-cell:/Users/ufuk/1.%20Research/AIMS/Project%20Repo/ESO/src/eso/utils/Create_Dataset.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> if start_idx == 0:
#       <a href='vscode-notebook-cell:/Users/ufuk/1.%20Research/AIMS/Project%20Repo/ESO/src/eso/utils/Create_Dataset.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a>     end_idx = n - 1
# ----> <a href='vscode-notebook-cell:/Users/ufuk/1.%20Research/AIMS/Project%20Repo/ESO/src/eso/utils/Create_Dataset.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> parent2_genes = parent2.get_genes()
#       <a href='vscode-notebook-cell:/Users/ufuk/1.%20Research/AIMS/Project%20Repo/ESO/src/eso/utils/Create_Dataset.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> for k in range(start_idx, end_idx):
# ...

# %%
from pathlib import Path

Path("")
# Out:
# PosixPath('.')

# %%
# species_folder = '/home/edufourq/Documents/AbsenceOptimisation/Matthew' # Should contain /Audio and /Annotations
species_folder = "/home/aaron-joel/Documents/PostDoc/EsoProject/data"
lowpass_cutoff = 2000  # Cutt off for low pass filter
downsample_rate = 4800  # Frequency to downsample to
nyquist_rate = 2400  # Nyquist rate (half of sampling rate)
segment_duration = 4  # how long should a segment be
augmentation_amount_positive_class = 1  # how many times should a segment be augmented
augmentation_amount_background_class = 1  # how many times should a segment be augmented
positive_class = [
    "gibbon"
]  # which labels should be bundled together for the positive  class
negative_class = [
    "no-gibbon"
]  # which labels should be bundled together for the negative  class
file_type = "svl"
audio_extension = ".wav"
n_fft = 1024  # Hann window length
hop_length = 256  # Sepctrogram hop size
n_mels = 128  # Spectrogram number of mells
f_min = 4000  # Spectrogram, minimum frequency for call
f_max = 9000  # Spectrogram, maximum frequency for call
save_results_folder = "Saved_Data"

# %%
# import preprocessing
from Preprocessing import *

prepro = Preprocessing(
    species_folder,
    lowpass_cutoff,
    downsample_rate,
    nyquist_rate,
    segment_duration,
    positive_class,
    negative_class,
    augmentation_amount_positive_class,
    augmentation_amount_background_class,
    n_fft,
    hop_length,
    n_mels,
    f_min,
    f_max,
    file_type,
    audio_extension,
)

# %%
nb_negative_class = 20

# %%
prepro = Preprocessing(
    species_folder,
    lowpass_cutoff,
    downsample_rate,
    nyquist_rate,
    segment_duration,
    positive_class,
    negative_class,
    nb_negative_class,
    n_fft,
    hop_length,
    n_mels,
    f_min,
    f_max,
    file_type,
    audio_extension,
    apply_preprocessing=True,
    testing_dataset=False,
)

# %%
dir(prepro)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_shuffle_files_names',
#  'add_extra_dim',
#  'annotations_path',
#  'apply_preprocessing',
#  'audio_extension',
#  'audio_path',
#  'augment_dataset',
#  'butter_lowpass',
#  'butter_lowpass_filter',
#  'check_distribution',
#  'convert_all_to_image',
#  'convert_single_to_image',
#  'create_dataset',
#  'downsample_file',
#  'downsample_rate',
#  'f_max',
#  'f_min',
#  'file_type',
#  'getXY',
#  'hop_length',
#  'load_data_from_pickle',
#  'lowpass_cutoff',
#  'n_ftt',
#  'n_mels',
#  'nb_negative_class',
#  'negative_class',
#  'nyquist_rate',
# ...

# %%
# Don't run this code every time. Resume from the cell below which loads from the pickled data!
# If you run this cell every time then it will become very time consuming!
# X, Y = pre_pro.create_dataset(False)

# pre_pro.save_data_to_pickle(X, Y)

X, Y = prepro.create_dataset(verbose=True)
# Out:
# Annotations path: /home/aaron-joel/Documents/PostDoc/EsoProject/data/Annotations/*.svl
# Audio path /home/aaron-joel/Documents/PostDoc/EsoProject/data/Audio/*.wav
# Processing: HGSM3A_0+1_20160408_185900
# Found file
# Filtering...
# Downsampling...
# Reading annotations...
# start_sec 55
# annotation_duration_seconds 55
# self.segment_duration  4
# segments_to_extract 52
# Semgnet 0 of 19
# *******************
# start frame 264000
# end frame 283200
# Semgnet 1 of 19
# *******************
# start frame 268800
# end frame 288000
# Semgnet 2 of 19
# *******************
# start frame 273600
# end frame 292800
# Semgnet 3 of 19
# *******************
# start frame 278400
# end frame 297600
# Semgnet 4 of 19
# *******************
# start frame 283200
# end frame 302400
# Semgnet 5 of 19
# *******************
# start frame 288000
# end frame 307200
# Semgnet 6 of 19
# *******************
# start frame 292800
# end frame 312000
# Semgnet 7 of 19
# *******************
# start frame 297600
# ...

# %%
type(X), type(Y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X.shape
# Out:
# (1182, 128, 76)

# %%
Y.shape
# Out:
# (1182,)

# %%
# Only save once, don't do this everytime!
prepro.save_data_to_pickle(X, Y)

# %%
# Once saved, you can load
X, Y = prepro.load_data_from_pickle()

# %%
X.shape
# Out:
# (1182, 128, 76)

# %%
X_aug, Y_aug = prepro.augment_dataset(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_aug, Y_aug = prepro.augment_dataset(X, Y)
#
# File ~/Documents/PostDoc/Eso_Project_/ESO/src/eso/utils/preprocessing.py:351, in Preprocessing.augment_dataset(self, X, Y)
#     348 Y_augmented.extend(Y)
#     350 for i in range(difference):
# --> 351     X_augmented.append(self.time_shifting(np.asarray(X), index))
#     352     Y_augmented.append(
#     353         np.unique(np.asarray(Y), return_counts=True)[0][label_to_augment]
#     354     )
#     356 return X_augmented, Y_augmented
#
# File ~/Documents/PostDoc/Eso_Project_/ESO/src/eso/utils/preprocessing.py:311, in Preprocessing.time_shifting(self, X, index)
#     308 random_time_point_segment = randint(1, len(segment) - 1)
#     310 # Apply time shift to the segment
# --> 311 segment = self.time_shift(segment, random_time_point_segment)
# ...

# %%
prepro.time_shift??
# Out:
# Signature: prepro.time_shift(audio, shift)
# Source:
#     def time_shift(self, audio, shift):
#         """
#         Shift amplitude values to the right by a random value.
#
#         The amplitude values are wrapped back to the left side of the waveform.
#
#         Args:
#             audio (ndarray): Array of amplitude values representing the audio waveform.
#             shift (int): Amount of shift to apply to the waveform.
#
#         Returns:
#             ndarray: Augmented waveform with the shifted amplitude values.
#         """
#
#         augmented = np.zeros(len(audio))
#         augmented[0:shift] = audio[-shift:]
#         augmented[shift:] = audio[:-shift]
#
#         return augmented
# File:      ~/Documents/PostDoc/Eso_Project_/ESO/src/eso/utils/preprocessing.py
# Type:      method

# %%
prepro.time_shifting??
# Out:
# Signature: prepro.time_shifting(X, index)
# Source:
#     def time_shifting(self, X, index):
#         """
#         Augment a segment of amplitude values by applying a time shift.
#
#         Args:
#             X (ndarray): Array of amplitude values.
#             X_meta (ndarray): Array of corresponding metadata.
#             index (list): List of indices of the files to choose from.
#
#         Returns:
#             tuple: Augmented segment and its metadata.
#         """
#         # Convert index to list
#         index = list(index)
#         # Randomly select an index from the given index list
#         idx_pickup = random.sample(index, 1)
#
#         # Retrieve the segment and metadata corresponding to the selected index
#         segment = X[idx_pickup][0]
#
#         # Randomly select time into the segments
#         random_time_point_segment = randint(1, len(segment) - 1)
#
#         # Apply time shift to the segment
# ...

# %%
distribution = prepro.check_distribution(Y)
print(distribution)
print("done")
# Out:
# {'gibbon': 462, 'no-gibbon': 720}
# done

# %%
distribution = prepro.check_distribution(Y)
print(distribution)
print("done")
# Out:
# {'gibbon': 462, 'no-gibbon': 720}
# done

# %%
# You have 2424 audio segments of length 19200 (amplitude values)
print("X", X.shape)
print("Y", Y.shape)
# Out:
# X (2424, 128, 76)
# Y (2424,)

# %%
# You have 2424 audio segments of length 19200 (amplitude values)
print("X", X.shape)
print("Y", Y.shape)
# Out:
# X (1182, 128, 76)
# Y (1182,)

# %% [markdown]
# ### Visualise some spectrograms

# %%
import librosa

# %%
import matplotlib

matplotlib.pyplot.get_backend()
# Out:
# 'agg'

# %%
index = 808
librosa.display.specshow(X[index, :, :], hop_length=1024, x_axis="time")
plt.show()
# Out:
# /tmp/ipykernel_24641/3462911291.py:3: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
index = 1808
librosa.display.specshow(X[index, :, :], hop_length=1024, x_axis="time")

# %%
index = 1808
librosa.display.specshow(X[index, :, :], hop_length=1024, x_axis="time")

# %%
Y[index]
# Out:
# 'no-gibbon'

# %%
index = 1952
librosa.display.specshow(X[index, :, :], hop_length=1024, x_axis="time")

# %%
Y[index]
# Out:
# 'no-gibbon'
